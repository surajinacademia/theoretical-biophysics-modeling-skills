# %% [markdown]
# # Research notebook title
#
# - Explain the scientific question and the context needed to understand it.
# - Explain why the calculation matters and what it will help establish.
# - Describe the approach and its essential assumptions in ordinary language.

# %%
import matplotlib.pyplot as plt
try:
    import minimalist
except ModuleNotFoundError as exc:
    if exc.name != 'minimalist':
        raise
    minimalist = None

if minimalist is not None:
    minimalist.use_style('white')
else:
    # Portable default; the owner's optional theme is not distributed here.
    plt.style.use('default')
# Add the scientific imports and task-relevant paths here.

# %% [markdown]
# ## Scientific approach
#
# Replace this authoring guidance with the governing equations or data transformations, assumptions, units, conditions, and an explanation of the calculation. Add further explanation-and-code pairs for distinct scientific stages when needed. Describe the checks that will support the intended claim.

# %%
def compute(parameters):
    # Explain the scientific or numerical decisions beside their implementation.
    raise NotImplementedError("Implement the agreed calculation and scientific checks.")

# %%
def plot_results(results, parameters):
    # Use plt.subplots() for a single panel, or an explicit figsize=(width, height) in inches for a panel grid.
    raise NotImplementedError("Implement the requested figures with labels and units.")

# %%
PARAMETERS = {
    # Use short physical names (e.g., 'length') and explain meaning and units in comments.
}

# %%
results = compute(PARAMETERS)
plot_results(results, PARAMETERS)
plt.show()
